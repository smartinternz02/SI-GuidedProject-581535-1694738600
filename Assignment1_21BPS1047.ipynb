# %%
import numpy as np
import pandas as pd

num_observations = 4
num_features = 4

random_values = np.random.rand(num_observations, num_features)

column_names = ['F1', 'F2', 'F3', 'F4']
df = pd.DataFrame(random_values, columns=column_names)
df
# Out:
#          F1        F2        F3        F4
# 0  0.740207  0.165599  0.206015  0.680662
# 1  0.381560  0.509779  0.922328  0.868902
# 2  0.361674  0.583545  0.706016  0.767385
# 3  0.835694  0.673162  0.624926  0.607856

# %%
#task2
df.rename({'F1': 'Random value 1', 'F2': 'Random value 2', 'F3': 'Random value 3', 'F4': 'Random value 4'}, axis=1, inplace=True)
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.740207        0.165599        0.206015        0.680662
# 1        0.381560        0.509779        0.922328        0.868902
# 2        0.361674        0.583545        0.706016        0.767385
# 3        0.835694        0.673162        0.624926        0.607856

# %%
#task3
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.579784        0.483021        0.614821        0.731201
# std          0.243646        0.221909        0.300056        0.112604
# min          0.361674        0.165599        0.206015        0.607856
# 25%          0.376588        0.423734        0.520198        0.662461
# 50%          0.560883        0.546662        0.665471        0.724024
# 75%          0.764079        0.605949        0.760094        0.792764
# max          0.835694        0.673162        0.922328        0.868902

# %%
#task4
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      float64
#  1   Random value 2  4 non-null      float64
#  2   Random value 3  4 non-null      float64
#  3   Random value 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
#task5
df['Random value 2']
# Out:
# 0    0.165599
# 1    0.509779
# 2    0.583545
# 3    0.673162
# Name: Random value 2, dtype: float64

# %%
#task5
df['Random value 3']
# Out:
# 0    0.206015
# 1    0.922328
# 2    0.706016
# 3    0.624926
# Name: Random value 3, dtype: float64

# %%
#task5
df.iloc[:, 1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.165599        0.206015
# 1        0.509779        0.922328
# 2        0.583545        0.706016
# 3        0.673162        0.624926
